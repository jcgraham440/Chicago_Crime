# %%
import pandas as pd
import numpy as np
import config

import sqlalchemy
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

pd.options.mode.chained_assignment = None

# %%
engine = create_engine(f'postgresql://postgres:{config.password}@localhost:5432/crime_db')

# %%
crime_df = pd.read_sql("chicago", con=engine)
crime_df.head()
# Out:
#    index        ID                Date       Primary_Type  \
# 0      0  11824091 2019-09-10 23:55:00  WEAPONS VIOLATION
# 1      1  11824149 2019-09-10 23:50:00      OTHER OFFENSE
# 2      2  11824121 2019-09-10 23:50:00            BATTERY
# 3      3  11824152 2019-09-10 23:47:00    CRIMINAL DAMAGE
# 4      5  11824113 2019-09-10 23:42:00            ASSAULT
#
#                  Description     Location_Description  Arrest District  Year  \
# 0       UNLAWFUL USE HANDGUN  RESIDENCE PORCH/HALLWAY   False      007  2019
# 1  VEHICLE TITLE/REG OFFENSE                   STREET    True      006  2019
# 2    DOMESTIC BATTERY SIMPLE                APARTMENT    True      015  2019
# 3                TO PROPERTY                RESIDENCE   False      006  2019
# 4                     SIMPLE                 SIDEWALK   False      015  2019
#
#     Latitude  Longitude Historical_Wards Zip_Codes Police_Districts
# 0  41.775402 -87.653178               17     21559               17
# 1  41.750582 -87.647984               17     21554               20
# 2  41.880829 -87.752634               11     22216               25
# 3  41.751657 -87.650131               17     21554               20
# 4  41.899880 -87.748366                4      4299               25

# %%
crime_types = ['THEFT', 'BATTERY', 'CRIMINAL DAMAGE', 'NARCOTICS', 'ASSAULT', 
    'MOTOR VEHICLE THEFT', 'ROBBERY', 'WEAPONS VIOLATION', 'HOMICIDE', 'ARSON']

filtered_crime_df = crime_df[crime_df.Primary_Type.isin(crime_types)]
filtered_crime_df.head()
# Out:
#    index        ID                Date       Primary_Type  \
# 0      0  11824091 2019-09-10 23:55:00  WEAPONS VIOLATION
# 2      2  11824121 2019-09-10 23:50:00            BATTERY
# 3      3  11824152 2019-09-10 23:47:00    CRIMINAL DAMAGE
# 4      5  11824113 2019-09-10 23:42:00            ASSAULT
# 7      8  11824122 2019-09-10 23:33:00            BATTERY
#
#                Description     Location_Description  Arrest District  Year  \
# 0     UNLAWFUL USE HANDGUN  RESIDENCE PORCH/HALLWAY   False      007  2019
# 2  DOMESTIC BATTERY SIMPLE                APARTMENT    True      015  2019
# 3              TO PROPERTY                RESIDENCE   False      006  2019
# 4                   SIMPLE                 SIDEWALK   False      015  2019
# 7  DOMESTIC BATTERY SIMPLE                    ALLEY    True      025  2019
#
#     Latitude  Longitude Historical_Wards Zip_Codes Police_Districts
# 0  41.775402 -87.653178               17     21559               17
# 2  41.880829 -87.752634               11     22216               25
# 3  41.751657 -87.650131               17     21554               20
# 4  41.899880 -87.748366                4      4299               25
# 7  41.919319 -87.758462                4     22615                6

# %%
filtered_crime_df['Hour'] = filtered_crime_df['Date'].dt.hour
filtered_crime_df['Month'] = filtered_crime_df['Date'].dt.month
filtered_crime_df['Day'] = filtered_crime_df['Date'].dt.day
filtered_crime_df['Day_of_Week'] = filtered_crime_df['Date'].dt.weekday_name
filtered_crime_df['Day_of_Year'] = filtered_crime_df['Date'].dt.dayofyear

filtered_crime_df.head()
# Out:
#    index        ID                Date       Primary_Type  \
# 0      0  11824091 2019-09-10 23:55:00  WEAPONS VIOLATION
# 2      2  11824121 2019-09-10 23:50:00            BATTERY
# 3      3  11824152 2019-09-10 23:47:00    CRIMINAL DAMAGE
# 4      5  11824113 2019-09-10 23:42:00            ASSAULT
# 7      8  11824122 2019-09-10 23:33:00            BATTERY
#
#                Description     Location_Description  Arrest District  Year  \
# 0     UNLAWFUL USE HANDGUN  RESIDENCE PORCH/HALLWAY   False      007  2019
# 2  DOMESTIC BATTERY SIMPLE                APARTMENT    True      015  2019
# 3              TO PROPERTY                RESIDENCE   False      006  2019
# 4                   SIMPLE                 SIDEWALK   False      015  2019
# 7  DOMESTIC BATTERY SIMPLE                    ALLEY    True      025  2019
#
#     Latitude  Longitude Historical_Wards Zip_Codes Police_Districts  Hour  \
# 0  41.775402 -87.653178               17     21559               17    23
# 2  41.880829 -87.752634               11     22216               25    23
# 3  41.751657 -87.650131               17     21554               20    23
# 4  41.899880 -87.748366                4      4299               25    23
# 7  41.919319 -87.758462                4     22615                6    23
#
#    Month  Day Day_of_Week  Day_of_Year
# 0      9   10     Tuesday          253
# 2      9   10     Tuesday          253
# 3      9   10     Tuesday          253
# 4      9   10     Tuesday          253
# 7      9   10     Tuesday          253

# %%
# inflation_df = pd.read_csv("assets/data/Consumer_Price_Index_All_Urban_Consumers.csv")
# inflation_df.head()

# unemployment_df = pd.read_csv("assets/data/Illinois_Unemployment_Rate_2009-2019.csv")
# unemployment_df.head()

# %%
# merged_df = pd.merge(filtered_crime_df, inflation_df, on=(['Year', 'Month']), how='inner').fillna('Unknown')
# second_merged_df = pd.merge(merged_df, unemployment_df, on=(['Year', 'Month']), how='inner').fillna('Unknown')
# second_merged_df.head()

# %%
# bins = [0, 6, 12, 18, 23]
# labels = ['Night','Morning','Afternoon','Evening']
# model_df['Hour_Binned'] = pd.cut(model_df['Hour'], bins=bins, labels=labels)

group_names = ['Night','Morning','Afternoon','Evening']
filtered_crime_df["Hour_Bins"] = pd.cut(filtered_crime_df.Hour, bins=4, labels=group_names)

# %%
filtered_crime_df.round({'Latitude': 2, 'Longitude': 2})
# Out:
#            index        ID                Date         Primary_Type  \
# 0              0  11824091 2019-09-10 23:55:00    WEAPONS VIOLATION
# 2              2  11824121 2019-09-10 23:50:00              BATTERY
# 3              3  11824152 2019-09-10 23:47:00      CRIMINAL DAMAGE
# 4              5  11824113 2019-09-10 23:42:00              ASSAULT
# 7              8  11824122 2019-09-10 23:33:00              BATTERY
# 8              9  11824162 2019-09-10 23:30:00              ROBBERY
# 9             10  11824148 2019-09-10 23:30:00              BATTERY
# 10            11  11824756 2019-09-10 23:30:00      CRIMINAL DAMAGE
# 11            12  11824127 2019-09-10 23:30:00                THEFT
# 2868951  2889566   8381214 2010-01-01 00:01:00                THEFT
# 2868952  2889568   8494410 2010-01-01 00:01:00                THEFT
# 2868953  2889570   8576265 2010-01-01 00:01:00                THEFT
# 2868954  2889572   8716926 2010-01-01 00:01:00                THEFT
# 2868956  2889576   8405290 2010-01-01 00:01:00                THEFT
#
#                             Description            Location_Description  \
# 0                  UNLAWFUL USE HANDGUN         RESIDENCE PORCH/HALLWAY
# 2               DOMESTIC BATTERY SIMPLE                       APARTMENT
# 3                           TO PROPERTY                       RESIDENCE
# 4                                SIMPLE                        SIDEWALK
# 7               DOMESTIC BATTERY SIMPLE                           ALLEY
# 8                 STRONGARM - NO WEAPON                        SIDEWALK
# 9               DOMESTIC BATTERY SIMPLE                       RESIDENCE
# 10                          TO PROPERTY   RESIDENTIAL YARD (FRONT/BACK)
# 11                            OVER $500                          STREET
# 14       POSS: CANNABIS MORE THAN 30GMS                          STREET
# 15             UNLAWFUL POSS OF HANDGUN                        SIDEWALK
# 16                       $500 AND UNDER                          STREET
# 17                            OVER $500                          STREET
# 18                       ARMED: HANDGUN                        SIDEWALK
# 19              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 20              DOMESTIC BATTERY SIMPLE                        SIDEWALK
# 21                           AUTOMOBILE                          STREET
# 22                           TO VEHICLE          VEHICLE NON-COMMERCIAL
# 23                       $500 AND UNDER   RESIDENTIAL YARD (FRONT/BACK)
# 26                               SIMPLE                       APARTMENT
# 27       AGGRAVATED:KNIFE/CUTTING INSTR                       APARTMENT
# 28                           TO VEHICLE          DRIVEWAY - RESIDENTIAL
# 29              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 32                         RETAIL THEFT              SMALL RETAIL STORE
# 33              DOMESTIC BATTERY SIMPLE                       RESIDENCE
# 34                       $500 AND UNDER          VEHICLE NON-COMMERCIAL
# 35              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 36                       $500 AND UNDER                          STREET
# 37                           TO VEHICLE          VEHICLE NON-COMMERCIAL
# 38                               SIMPLE                        SIDEWALK
# ...                                 ...                             ...
# 2868887   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868888                     TO PROPERTY  FACTORY/MANUFACTURING BUILDING
# 2868896                   FROM BUILDING                       RESIDENCE
# 2868897                       OVER $500           MEDICAL/DENTAL OFFICE
# 2868900                       OVER $500                       RESIDENCE
# 2868907   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868910  FINANCIAL ID THEFT:$300 &UNDER                       RESIDENCE
# 2868911   FINANCIAL ID THEFT: OVER $300                          STREET
# 2868912                   FROM BUILDING                       APARTMENT
# 2868913   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868914                     TO PROPERTY                       RESIDENCE
# 2868919   FINANCIAL ID THEFT: OVER $300                           OTHER
# 2868920   FINANCIAL ID THEFT: OVER $300                       APARTMENT
# 2868928   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868929   FINANCIAL ID THEFT: OVER $300                           OTHER
# 2868930                  $500 AND UNDER                       APARTMENT
# 2868931  FINANCIAL ID THEFT:$300 &UNDER                       RESIDENCE
# 2868932   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868933   FINANCIAL ID THEFT: OVER $300                           OTHER
# 2868936   FINANCIAL ID THEFT: OVER $300                           OTHER
# 2868937   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2868941   FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# 2
# 2868949     22618                6     0      1    1      Friday            1
# 2868951     21560                7     0      1    1      Friday            1
# 2868952     21559               17     0      1    1      Friday            1
# 2868953     21554                9     0      1    1      Friday            1
# 2868954     21546               18     0      1    1      Friday            1
# 2868956     22216               25     0      1    1      Friday            1
#
#         Hour_Bins
# 0         Evening
# 2         Evening
# 3         Evening
# 4         Evening
# 7         Evening
# 8         Evening
# 9         Evening
# 10        Evening
# 11        Evening
# 14        Evening
# 15        Evening
# 16        Evening
# 17        Evening
# 18        Evening
# 19        Evening
# 20        Evening
# 21        Evening
# 22        Evening
# 23        Evening
# 26        Evening
# 27        Evening
# 28        Evening
# 29        Evening
# 32        Evening
# 33        Evening
# 34        Evening
# 35        Evening
# 36        Evening
# 37        Evening
# 38        Evening
# ...           ...
# 2868887     Night
# 2868888     Night
# 2868896     Night
# 2868897     Night
# 2868900     Night
# 2868907     Night
# 2868910     Night
# 2868911     Night
# 2868912     Night
# 2868913     Night
# 2868914     Night
# 2868919     Night
# 2868920     Night
# 2868928     Night
# 2868929     Night
# 2868930     Night
# 2868931     Night
# 2868932     Night
# 2868933     Night
# 2868936     Night
# 2868937     Night
# 2868941     Night
# 2868943     Night
# 2868947     Night
# 2868949     Night
# 2868951     Night
# 2868952     Night
# 2868953     Night
# 2868954     Night
# 2868956     Night
#
# [2199080 rows x 20 columns]

# %%
#List of relevant columns for model
col_list = [ 'Year','Month','Day_of_Week','Hour_Bins','Primary_Type','Latitude',
            'Longitude','Location_Description', 'Arrest','Zip_Codes', 'Police_Districts']

#Dataframe created from list of relevant columns
model_df = filtered_crime_df[col_list]
model_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2199080 entries, 0 to 2868956
# Data columns (total 11 columns):
# Year                    int64
# Month                   int64
# Day_of_Week             object
# Hour_Bins               category
# Primary_Type            object
# Latitude                float64
# Longitude               float64
# Location_Description    object
# Arrest                  bool
# Zip_Codes               object
# Police_Districts        object
# dtypes: bool(1), category(1), float64(2), int64(2), object(5)
# memory usage: 172.0+ MB

# %%
null_columns = model_df.columns[model_df.isnull().any()]
model_df[null_columns].isnull().sum()
# Out:
# Location_Description    707
# dtype: int64

# %%
model_df["Location_Description"].fillna("Unknown", inplace = True)

# %%
# model_df = model_df[:25000]

# %%
X = model_df.drop(['Primary_Type'], axis=1)
y = model_df['Primary_Type']

print(X.shape)
print(y.shape)
# Out:
# (2199080, 10)
# (2199080,)

# %%
#encode string variables for input into the classification model:
encoded_X = pd.get_dummies(X, columns=['Location_Description', 'Zip_Codes', 'Hour_Bins', 'Day_of_Week','Police_Districts'])
print(encoded_X.shape)
# encoded_y = pd.get_dummies(y, columns=['Primary_Type'])
# Out:
# (2199080, 286)

# %%
# create scaler
scaler = MinMaxScaler()
normalized_X = scaler.fit_transform(encoded_X)
# Out:
# /anaconda2/envs/LearnPython3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.25, random_state = 21)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# /anaconda2/envs/LearnPython3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda2/envs/LearnPython3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
#

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.4752096331193044
# [[    34     22    313    232      1     23     36     15    372      5]
#  [    17   3119  18702   4200     15   1260   4309   1312  13337    255]
#  [    39   6049  68538  11473     34   2766   8990   4233  27311    574]
#  [    31   2396  20694  17784     32   4868   1888   1154  27947    195]
#  [     2     22    272    140    257     96    195     31    217     18]
#  [     8    715   3210   6009     23   6521   1467    670  12874     89]
#  [     6    816   5694    313     13    184  53333    135    866    828]
#  [     7   1024   9519   2335     16   1313   1381   3960   8623     73]
#  [    48   3876  24754  14981     20   6330   2083   2706 107137    153]
#  [     1    312   2643    376      8    145   5018    148    608    573]]
#                      precision    recall  f1-score   support
#
#               ARSON       0.18      0.03      0.05      1053
#             ASSAULT       0.17      0.07      0.10     46526
#             BATTERY       0.44      0.53      0.48    130007
#     CRIMINAL DAMAGE       0.31      0.23      0.26     76989
#            HOMICIDE       0.61      0.21      0.31      1250
# MOTOR VEHICLE THEFT       0.28      0.21      0.24     31586
#           NARCOTICS       0.68      0.86      0.76     62188
#             ROBBERY       0.28      0.14      0.19     28251
#               THEFT       0.54      0.66      0.59    162088
#   WEAPONS VIOLATION       0.21      0.06      0.09      9832
#
#           micro avg       0.48      0.48      0.48    549770
#           macro avg       0.37      0.30      0.31    549770
#        weighted avg       0.43      0.48      0.45    549770

# %%
grad_class = GradientBoostingClassifier(learning_rate=0.1,n_estimators = 10, random_state = 42)
grad_class.fit(X_train, y_train)
y_pred_grad = grad_class.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred)) 
print(classification_report(y_test,y_pred_grad))
# Out:
# 0.4752096331193044
# [[    34     22    313    232      1     23     36     15    372      5]
#  [    17   3119  18702   4200     15   1260   4309   1312  13337    255]
#  [    39   6049  68538  11473     34   2766   8990   4233  27311    574]
#  [    31   2396  20694  17784     32   4868   1888   1154  27947    195]
#  [     2     22    272    140    257     96    195     31    217     18]
#  [     8    715   3210   6009     23   6521   1467    670  12874     89]
#  [     6    816   5694    313     13    184  53333    135    866    828]
#  [     7   1024   9519   2335     16   1313   1381   3960   8623     73]
#  [    48   3876  24754  14981     20   6330   2083   2706 107137    153]
#  [     1    312   2643    376      8    145   5018    148    608    573]]
# /anaconda2/envs/LearnPython3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                      precision    recall  f1-score   support
#
#               ARSON       0.00      0.00      0.00      1053
#             ASSAULT       0.00      0.00      0.00     46526
#             BATTERY       0.46      0.53      0.49    130007
#     CRIMINAL DAMAGE       0.58      0.04      0.08     76989
#            HOMICIDE       1.00      0.22      0.37      1250
# MOTOR VEHICLE THEFT       0.00      0.00      0.00     31586
#           NARCOTICS       0.57      0.93      0.71     62188
#             ROBBERY       0.40      0.01      0.02     28251
#               THEFT       0.44      0.80      0.57    162088
#   WEAPONS VIOLATION       0.00      0.00      0.00      9832
#
#           micro avg       0.47      0.47      0.47    549770
#           macro avg       0.35      0.25      0.22    549770
#        weighted avg       0.41      0.47      0.38    549770

# %%
from tpot import TPOTClassifier
pipeline_optimizer = TPOTClassifier()

pipeline_optimizer = TPOTClassifier(generations=5, population_size=20, cv=5,
                                    random_state=42, verbosity=2, warm_start=True)

pipeline_optimizer.fit(X_train, y_train)

print(pipeline_optimizer.score(X_test, y_test))

# %%
pipeline_optimizer.export('tpot_exported_pipeline.py')
